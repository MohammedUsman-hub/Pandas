# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
import webbrowser 
website ='https://en.wikipedia.org/wiki/FIFA_World_Cup_records_and_statistics#:~:text=Eight%20nations%20have%20won%20the,appeared%20in%20the%20semi%2Dfinals'
webbrowser.open(website)
# Out:
# True

# %%
worldcup_frame = pd.read_clipboard()

# %%
worldcup_frame
# Out:
#    Rank         Team  Part  Pld   W   D   L   GF   GA    GD  Pts
# 0     1       Brazil    22  114  76  19  19  237  108  +129  247
# 1     2   Germany[a]    20  112  68  21  23  232  130  +102  225
# 2     3    Argentina    18   88  47  17  24  152  101   +51  158
# 3     4        Italy    18   83  45  21  17  128   77   +51  156
# 4     5       France    16   73  39  14  20  136   85   +51  131
# 5     6      England    16   74  32  22  20  104   68   +36  118
# 6     7        Spain    16   67  31  17  19  108   75   +33  110
# 7     8  Netherlands    11   55  30  14  11   96   52   +44  104
# 8     9      Uruguay    14   59  25  13  21   89   76   +13   88
# 9    10      Belgium    14   51  21  10  20   69   74    −5   73

# %%
worldcup_frame.columns
# Out:
# Index(['Rank', 'Team', 'Part', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts'], dtype='object')

# %%
worldcup_frame.Team
# Out:
# 0         Brazil
# 1     Germany[a]
# 2      Argentina
# 3          Italy
# 4         France
# 5        England
# 6          Spain
# 7    Netherlands
# 8        Uruguay
# 9        Belgium
# Name: Team, dtype: object

# %%
DataFrame(worldcup_frame, columns=['Team', 'Pld', 'W','D','L', 'Pts'])
# Out:
#           Team  Pld   W   D   L  Pts
# 0       Brazil  114  76  19  19  247
# 1   Germany[a]  112  68  21  23  225
# 2    Argentina   88  47  17  24  158
# 3        Italy   83  45  21  17  156
# 4       France   73  39  14  20  131
# 5      England   74  32  22  20  118
# 6        Spain   67  31  17  19  110
# 7  Netherlands   55  30  14  11  104
# 8      Uruguay   59  25  13  21   88
# 9      Belgium   51  21  10  20   73

# %%
worldcup_frame.head(6)
# Out:
#    Rank        Team  Part  Pld   W   D   L   GF   GA    GD  Pts
# 0     1      Brazil    22  114  76  19  19  237  108  +129  247
# 1     2  Germany[a]    20  112  68  21  23  232  130  +102  225
# 2     3   Argentina    18   88  47  17  24  152  101   +51  158
# 3     4       Italy    18   83  45  21  17  128   77   +51  156
# 4     5      France    16   73  39  14  20  136   85   +51  131
# 5     6     England    16   74  32  22  20  104   68   +36  118

# %%
worldcup_frame.loc[2]
# Out:
# Rank            3
# Team    Argentina
# Part           18
# Pld            88
# W              47
# D              17
# L              24
# GF            152
# GA            101
# GD            +51
# Pts           158
# Name: 2, dtype: object

# %%
worldcup_frame['Stadium'] = "Wembley Stadium"

# %%
worldcup_frame
# Out:
#    Rank         Team  Part  Pld   W   D   L   GF   GA    GD  Pts  \
# 0     1       Brazil    22  114  76  19  19  237  108  +129  247
# 1     2   Germany[a]    20  112  68  21  23  232  130  +102  225
# 2     3    Argentina    18   88  47  17  24  152  101   +51  158
# 3     4        Italy    18   83  45  21  17  128   77   +51  156
# 4     5       France    16   73  39  14  20  136   85   +51  131
# 5     6      England    16   74  32  22  20  104   68   +36  118
# 6     7        Spain    16   67  31  17  19  108   75   +33  110
# 7     8  Netherlands    11   55  30  14  11   96   52   +44  104
# 8     9      Uruguay    14   59  25  13  21   89   76   +13   88
# 9    10      Belgium    14   51  21  10  20   69   74    −5   73
#
#            Stadium
# 0  Wembley Stadium
# 1  Wembley Stadium
# 2  Wembley Stadium
# 3  Wembley Stadium
# 4  Wembley Stadium
# 5  Wembley Stadium
# 6  Wembley Stadium
# 7  Wembley Stadium
# 8  Wembley Stadium
# 9  Wembley Stadium

# %%
worldcup_frame['Stadium'] = np.arange(10)

# %%
worldcup_frame
# Out:
#    Rank         Team  Part  Pld   W   D   L   GF   GA    GD  Pts  Stadium
# 0     1       Brazil    22  114  76  19  19  237  108  +129  247        0
# 1     2   Germany[a]    20  112  68  21  23  232  130  +102  225        1
# 2     3    Argentina    18   88  47  17  24  152  101   +51  158        2
# 3     4        Italy    18   83  45  21  17  128   77   +51  156        3
# 4     5       France    16   73  39  14  20  136   85   +51  131        4
# 5     6      England    16   74  32  22  20  104   68   +36  118        5
# 6     7        Spain    16   67  31  17  19  108   75   +33  110        6
# 7     8  Netherlands    11   55  30  14  11   96   52   +44  104        7
# 8     9      Uruguay    14   59  25  13  21   89   76   +13   88        8
# 9    10      Belgium    14   51  21  10  20   69   74    −5   73        9

# %%
stadiums = Series(["Wembley", "Old Trafford", "London Stadium"], index=[2,0, 5
                                                                    ])

# %%
stadiums
# Out:
# 2           Wembley
# 0      Old Trafford
# 5    London Stadium
# dtype: object

# %%
worldcup_frame['Stadium'] = stadiums

# %%
worldcup_frame
# Out:
#    Rank         Team  Part  Pld   W   D   L   GF   GA    GD  Pts  \
# 0     1       Brazil    22  114  76  19  19  237  108  +129  247
# 1     2   Germany[a]    20  112  68  21  23  232  130  +102  225
# 2     3    Argentina    18   88  47  17  24  152  101   +51  158
# 3     4        Italy    18   83  45  21  17  128   77   +51  156
# 4     5       France    16   73  39  14  20  136   85   +51  131
# 5     6      England    16   74  32  22  20  104   68   +36  118
# 6     7        Spain    16   67  31  17  19  108   75   +33  110
# 7     8  Netherlands    11   55  30  14  11   96   52   +44  104
# 8     9      Uruguay    14   59  25  13  21   89   76   +13   88
# 9    10      Belgium    14   51  21  10  20   69   74    −5   73
#
#           Stadium
# 0    Old Trafford
# 1             NaN
# 2         Wembley
# 3             NaN
# 4             NaN
# 5  London Stadium
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN

# %%
del worldcup_frame['Stadium']

# %%
worldcup_frame
# Out:
#    Rank         Team  Part  Pld   W   D   L   GF   GA    GD  Pts
# 0     1       Brazil    22  114  76  19  19  237  108  +129  247
# 1     2   Germany[a]    20  112  68  21  23  232  130  +102  225
# 2     3    Argentina    18   88  47  17  24  152  101   +51  158
# 3     4        Italy    18   83  45  21  17  128   77   +51  156
# 4     5       France    16   73  39  14  20  136   85   +51  131
# 5     6      England    16   74  32  22  20  104   68   +36  118
# 6     7        Spain    16   67  31  17  19  108   75   +33  110
# 7     8  Netherlands    11   55  30  14  11   96   52   +44  104
# 8     9      Uruguay    14   59  25  13  21   89   76   +13   88
# 9    10      Belgium    14   51  21  10  20   69   74    −5   73

# %%
data = {'Player':['Jordan','Bird','Kobe'],'Points':[23434, 23432, 22341]}

# %%
nba_points = DataFrame(data)

# %%
nba_points
# Out:
#    Player  Points
# 0  Jordan   23434
# 1    Bird   23432
# 2    Kobe   22341
