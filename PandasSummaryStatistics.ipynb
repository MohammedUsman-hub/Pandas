# %%
import pandas as pd
import numpy as np

from pandas import DataFrame, Series
from numpy.random import randn

# %%
arr = np.array([[1,2,np.nan], [np.nan,3,4]])

# %%
dframe1 = DataFrame(arr, index=['A','B'],columns=['One','Two','Three'])

dframe1
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.sum()
# Out:
# One      1.0
# Two      5.0
# Three    4.0
# dtype: float64

# %%
dframe1.sum(axis=1)
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe1.min()
# Out:
# One      1.0
# Two      2.0
# Three    4.0
# dtype: float64

# %%
dframe1.idxmin()
# Out:
# One      A
# Two      A
# Three    B
# dtype: object

# %%
dframe1.cumsum()
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  5.0    4.0

# %%
dframe1.describe() #Provide summary statistics on your DataFrame
# Out:
#        One       Two  Three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('xGbpuFNR1ME')

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html' # Web scraping 

nba = pd.read_html(url, header = 0)
nba
# Out:
# [      Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
#  0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
#  1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
#  2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
#  3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
#  4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
#  ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
#  729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
#  730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
#  731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
#  732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
#  733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
# ...

# %%
len(nba)
# Out:
# 1

# %%
nba[0]
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
# 1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
# 2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
# 3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
# 730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
# 733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
nba2019=nba[0]


nba2019[nba2019.Age == 'Age']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 22   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 49   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 70   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 97   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 132  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 161  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 186  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 217  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 244  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 269  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 299  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
len(nba2019[nba2019.Age == 'Age'])
# Out:
# 26

# %%
nba = nba2019.drop(nba2019[nba2019.Age == 'Age'].index)

# %%
nba.shape
# Out:
# (708, 30)

# %%
import seaborn as sns

# %%
sns.distplot(nba.PTS, kde=False)
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_12772\559888287.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(nba.PTS, kde=False)
# <Axes: xlabel='PTS'>

# %%
sns.distplot(nba.PTS, kde=False, hist_kws=dict(edgecolor='black', linewidth=2))
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_12772\3014282537.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(nba.PTS, kde=False, hist_kws=dict(edgecolor='black', linewidth=2))
# <Axes: xlabel='PTS'>

# %%
sns.distplot(nba.PTS, kde=False, hist_kws=dict(edgecolor='black', linewidth=2),color='#00bfc4')
# Out:
# C:\Users\Niko\AppData\Local\Temp\ipykernel_12772\3959807065.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(nba.PTS, kde=False, hist_kws=dict(edgecolor='black', linewidth=2),color='#00bfc4')
# <Axes: xlabel='PTS'>

# %%
#from pandas_datareader import data as pdweb
#import datetime

from pandas_datareader import data as pdr                #import pandas datareader

import yfinance as yf                                                          # you will need to install it if haven't done it already

yf.pdr_override()                                                                  #override the data reader function

# %%
#prices = data.DataReader(['CVX','XOM','BP'],'yahoo',start = datetime.datetime(2010,1,1),end = datetime.datetime(2010,1,15))['Adj Close']
prices = pdr.get_data_yahoo( ['CVX','XOM','BP'] , start="2010-01-01", end="2013-01-01")
prices.head()
# Out:
# [*********************100%%**********************]  3 of 3 completed
# 3 Failed downloads:
# ['BP', 'CVX', 'XOM']: OperationalError('unable to open database file')
# Empty DataFrame
# Columns: [(Adj Close, BP), (Adj Close, CVX), (Adj Close, XOM), (Close, BP), (Close, CVX), (Close, XOM), (High, BP), (High, CVX), (High, XOM), (Low, BP), (Low, CVX), (Low, XOM), (Open, BP), (Open, CVX), (Open, XOM), (Volume, BP), (Volume, CVX), (Volume, XOM)]
# Index: []
